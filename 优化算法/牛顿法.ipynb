# %% [markdown]
# ## 牛顿法理论  https://zhuanlan.zhihu.com/p/105265432

# %%
# %time
# 实现根号的代码
def sqrt(n,max_iter=1000):
    last_x=n/2
    eta=1e-10
    for i in range(max_iter):
        x=last_x- (last_x**2-n)/(2*last_x)
        if abs(x-last_x)<eta:
            break
        last_x=x
    return last_x
sqrt(2)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 6.91 µs
# 1.4142135623746899

# %%
import math
math.sqrt(1)
# Out:
# 1.0

# %% [markdown]
# Newton法
# Rosenbrock函数
# 函数 $f(x)=100*(x(2)-x(1).^2).^2+(1-x(1)).^2 $
# 梯度 $g(x)=(-400*(x(2)-x(1)^2)*x(1)-2*(1-x(1)),200*(x(2)-x(1)^2))^(T)$

# %%
# Out:
# 第0次的迭代结果为：[0.05 0.  ]
# 第1次的迭代结果为：[0.08583333 0.0015    ]
# 第2次的迭代结果为：[0.10536555 0.00351201]
# 第3次的迭代结果为：[0.12048577 0.00581607]
# 第4次的迭代结果为：[0.13438262 0.00846658]
# 第5次的迭代结果为：[0.13503464 0.00861216]
# 第6次的迭代结果为：[0.13571299 0.00878016]
# 第7次的迭代结果为：[0.13642817 0.0089691 ]
# 第8次的迭代结果为：[0.1371591  0.00917085]
# 第9次的迭代结果为：[0.13789639 0.00938081]
# 第10次的迭代结果为：[0.13789639 0.00938081]
# 第11次的迭代结果为：[0.43400616 0.09711627]
# 第12次的迭代结果为：[0.19441785 0.03244799]
# 第13次的迭代结果为：[0.23366735 0.04808779]
# 第14次的迭代结果为：[0.5554928  0.17981899]
# 第15次的迭代结果为：[0.26332952 0.06365937]
# 第16次的迭代结果为：[0.28807567 0.07666032]
# 第17次的迭代结果为：[0.5903991  0.23784259]
# 第18次的迭代结果为：[0.31950847 0.09601038]
# 第19次的迭代结果为：[0.34503828 0.11182081]
# 第20次的迭代结果为：[0.58709742 0.26392077]
# 第21次的迭代结果为：[0.3803235  0.13600225]
# 第22次的迭代结果为：[0.40597931 0.1538868 ]
# 第23次的迭代结果为：[0.53531262 0.24594925]
# 第24次的迭代结果为：[0.45178959 0.1881777 ]
# 第25次的迭代结果为：[0.46885577 0.20174156]
# 第26次的迭代结果为：[0.51738144 0.24172474]
# 第27次的迭代结果为：[0.51198285 0.23858353]
# 第28次的迭代结果为：[0.49445457 0.23056355]
# 第29次的迭代结果为：[0.49160067 0.2317114 ]
# 第30次的迭代结果为：[0.49133722 0.23772241]
# 第31次的迭代结果为：[0.49133722 0.23772241]
# 第32次的迭代结果为：[0.49545187 0.24544462]
# 第33次的迭代结果为：[0.50583286 0.26122552]
# 第34次的迭代结果为：[0.51820901 0.27777837]
# 第35次的迭代结果为：[0.54484272 0.31194108]
# 第36次的迭代结果为：[0.60129212 0.38309692]
# 第37次的迭代结果为：[0.67937488 0.48149139]
# 第38次的迭代结果为：[0.67937488 0.48149139]
# 第39次的迭代结果为：[0.69534574 0.4832706 ]
# 第40次的迭代结果为：[0.71233925 0.50432789]
# 第41次的迭代结果为：[0.77958343 0.5906512 ]
# 第42次的迭代结果为：[0.75079346 0.55555768]
# 第43次的迭代结果为：[0.75750597 0.56596895]
# 第44次的迭代结果为：[0.85186982 0.71428928]
# 第45次的迭代结果为：[0.85749885 0.72831222]
# 第46次的迭代结果为：[0.89279689 0.79613245]
# 第47次的迭代结果为：[0.9370388  0.87595143]
# 第48次的迭代结果为：[0.97620892 0.94869688]
# 第49次的迭代结果为：[0.97315219 0.94499492]
# 第50次的迭代结果为：[0.98039061 0.9609234 ]
# 第51次的迭代结果为：[0.98945144 0.97920306]
# 第52次的迭代结果为：[0.99905992 0.99816404]
# 第53次的迭代结果为：[1.00007963 1.00015789]
# 第54次的迭代结果为：[1.00000251 1.00000578]
# 第55次的迭代结果为：[1.00000079 1.00000187]
# 第56次的迭代结果为：[1. 1.]
# [1. 1.] 7.697136248620987e-16 57
